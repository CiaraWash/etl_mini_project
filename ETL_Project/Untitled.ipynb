# %%
import pandas as pd

# %%
pd.options.display.max_colwidth = 200


jobs_industrydf = pd.read_csv("Resources/Jobs_Industry_AllAreas_1998_2021.csv")
jobs_industrydf
# Out:
#                                                                                             GeoFIPS  \
# 0                                                                                           "00000"
# 1                                                                                           "00000"
# 2                                                                                           "00000"
# 3                                                                                           "00000"
# 4                                                                                           "00000"
# ...                                                                                             ...
# 7079                                                                                        "98000"
# 7080                                                          Note: See the included footnote file.
# ...

# %%
jobs_industrydf = jobs_industrydf.dropna()

# %%
jobs_industrydf
# Out:
#        GeoFIPS        GeoName Region TableName  LineCode  \
# 0      "00000"  United States         SAEMP25N      10.0
# 1      "00000"  United States         SAEMP25N      20.0
# 2      "00000"  United States         SAEMP25N      40.0
# 3      "00000"  United States         SAEMP25N      50.0
# 4      "00000"  United States         SAEMP25N      60.0
# ...        ...            ...    ...       ...       ...
# 7075   "98000"       Far West      8  SAEMP25N    2001.0
# 7076   "98000"       Far West      8  SAEMP25N    2002.0
# 7077   "98000"       Far West      8  SAEMP25N    2010.0
# 7078   "98000"       Far West      8  SAEMP25N    2011.0
# 7079   "98000"       Far West      8  SAEMP25N    2012.0
#
#      IndustryClassification                          Description  \
# 0                       ...   Total employment (number of jobs)
# 1                       ...          Wage and salary employment
# 2                       ...              Proprietors employment
# ...

# %%
reducedjobs_df = jobs_industrydf[[""]]
